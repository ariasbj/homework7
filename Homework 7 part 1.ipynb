# %%
import numpy as np 
import pandas as pd

# %%
df_AOC = pd.read_json("AOC_recent_tweets")
df_AOC_ID = df_AOC.loc[0:, "id"]
df_AOC_ID
# Out:
# 0       1358149122264563712
# 1       1358147616400408576
# 2       1358145332316667909
# 3       1358145218407759875
# 4       1358144207333036040
#                ...
# 3242    1181935928249606146
# 3243    1181932554552827905
# 3244    1181932460516478976
# 3245    1181927615340453899
# 3246    1181804625588051968
# Name: id, Length: 3247, dtype: int64

# %%
df_AOC
# Out:
#                     created_at                   id               id_str  \
# 0    2021-02-06 20:22:38+00:00  1358149122264563712  1358149122264563712
# 1    2021-02-06 20:16:39+00:00  1358147616400408576  1358147616400408576
# 2    2021-02-06 20:07:35+00:00  1358145332316667909  1358145332316667904
# 3    2021-02-06 20:07:07+00:00  1358145218407759875  1358145218407759872
# 4    2021-02-06 20:03:06+00:00  1358144207333036040  1358144207333036032
# ...                        ...                  ...                  ...
# 3242 2019-10-09 14:14:19+00:00  1181935928249606146  1181935928249606144
# 3243 2019-10-09 14:00:54+00:00  1181932554552827905  1181932554552827904
# 3244 2019-10-09 14:00:32+00:00  1181932460516478976  1181932460516478976
# 3245 2019-10-09 13:41:17+00:00  1181927615340453899  1181927615340453888
# 3246 2019-10-09 05:32:34+00:00  1181804625588051968  1181804625588051968
#
#                                               full_text  truncated  \
# ...

# %%
import datetime as dt
created_at = df_AOC.loc[:, "created_at"]
def time_in_hours(x):
    return x.hour + x.minute/60 + x.second/3600
dec_hours = created_at.apply(time_in_hours)
dec_hours
# Out:
# 0       20.377222
# 1       20.277500
# 2       20.126389
# 3       20.118611
# 4       20.051667
#           ...
# 3242    14.238611
# 3243    14.015000
# 3244    14.008889
# 3245    13.688056
# 3246     5.542778
# Name: created_at, Length: 3247, dtype: float64

# %%
df_AOC.insert(0, "hours", dec_hours)
df_AOC
# Out:
#           hours                created_at                   id  \
# 0     20.377222 2021-02-06 20:22:38+00:00  1358149122264563712
# 1     20.277500 2021-02-06 20:16:39+00:00  1358147616400408576
# 2     20.126389 2021-02-06 20:07:35+00:00  1358145332316667909
# 3     20.118611 2021-02-06 20:07:07+00:00  1358145218407759875
# 4     20.051667 2021-02-06 20:03:06+00:00  1358144207333036040
# ...         ...                       ...                  ...
# 3242  14.238611 2019-10-09 14:14:19+00:00  1181935928249606146
# 3243  14.015000 2019-10-09 14:00:54+00:00  1181932554552827905
# 3244  14.008889 2019-10-09 14:00:32+00:00  1181932460516478976
# 3245  13.688056 2019-10-09 13:41:17+00:00  1181927615340453899
# 3246   5.542778 2019-10-09 05:32:34+00:00  1181804625588051968
#
#                    id_str                                          full_text  \
# 0     1358149122264563712  RT @RepEscobar: Our country has the moral obli...
# ...

# %%
new_dataframe = df_AOC[["hours", "created_at", "full_text"]]
new_dataframe
# Out:
#           hours                created_at  \
# 0     20.377222 2021-02-06 20:22:38+00:00
# 1     20.277500 2021-02-06 20:16:39+00:00
# 2     20.126389 2021-02-06 20:07:35+00:00
# 3     20.118611 2021-02-06 20:07:07+00:00
# 4     20.051667 2021-02-06 20:03:06+00:00
# ...         ...                       ...
# 3242  14.238611 2019-10-09 14:14:19+00:00
# 3243  14.015000 2019-10-09 14:00:54+00:00
# 3244  14.008889 2019-10-09 14:00:32+00:00
# 3245  13.688056 2019-10-09 13:41:17+00:00
# 3246   5.542778 2019-10-09 05:32:34+00:00
#
#                                               full_text
# 0     RT @RepEscobar: Our country has the moral obli...
# 1     RT @RoKhanna: What happens when we guarantee $...
# 2                     (Source: https://t.co/3o5JEr6zpd)
# 3     Joe Cunningham pledged to never take corporate...
# 4     What’s even more gross is that Mace takes corp...
# ...                                                 ...
# 3242  Autocrats: “Jump!”\nTrump: “How high?”\n\n- Tr...
# ...

# %%
new_dataframe.to_csv('new_dataframe.csv', index=True)
